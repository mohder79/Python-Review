# %% [markdown]
# لیست میتونه هر داده باشه توش حتی خود لیست هم میشه*
#
#
#
#
# > Indented block

# %%
list=[1 , 5.6 , 'hi', True , [45,'x', 4.5] , 'mohder']
print(list)
# Out:
# [1, 5.6, 'hi', True, [45, 'x', 4.5], 'mohder']

# %% [markdown]
# برای دریافت یک مقدار از لیست میتونیم شماره اندیکسش رو بنویسیم و دریافتش کنیم

# %% [markdown]
# مقدار اندیکس از ۰ شروع میشه  و اگر از اخر لیست بخوایم میشه  -1

# %%
print(list[2] ,list[-1] )
# Out:
# hi mohder
