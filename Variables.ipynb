# %% [markdown]
# varibels are containers for storing data

# %%
name = 'mohder'
age = '22'
print(f'{name} age is {age}')
# Out:
# mohder age is 22

# %%
x = 2.45
y= 3
print(x*y)
# Out:
# 7.3500000000000005

# %% [markdown]
# we can specify data type of variable

# %%
x=str(172.5)  #its string 
y=int(5)
z= float(34.5)
print(f'{y*z} = {x}')
# Out:
# 172.5 = 172.5

# %% [markdown]
# Legal variable names:

# %%
myvar = "John"
my_var = "John"
_my_var = "John"
myVar = "John"
MYVAR = "John"
myvar2 = "John"

# %% [markdown]
# Illegal variable names:

# %%
2myvar = "John"
my-var = "John"
my var = "John"
# Out:
#   File "<ipython-input-10-0e82719f22b4>", line 1
#     2myvar = "John"
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# muliple variable

# %%
x,y,z,name = 11 , 2, 'my name is' , 'mohder'

print(f'{z} {name} and my age is {x*y}')
# Out:
# my name is mohder and my age is 22

# %%
list = [11 , 2, 'my name is' , 'mohder']
x,y,z,name = list
print(f'{z} {name} and my age is {x*y}')
# Out:
# my name is mohder and my age is 22

# %% [markdown]
# Global Variables

# %%
x , y , z  = 10 , 2 , 2
a= x*y+z

def myage(age:int): 
  print(f'my age is {age}')

myage(a)
# Out:
# my age is 22

# %%
x , y , z  = 10 , 2 , 2
a= x*y+z

def myage(age:int): 
  a = 23
  print(f'my age is {age}')

myage(a)

print("my age is",a)
# Out:
# my age is 22
# my age is 22

# %% [markdown]
# The global Keyword
# if use 'global' keyword , variable belongs golbal

# %%
def myage(): 
  global age
  age = 22
  print(f'my age is {age}')

myage()
# Out:
# my age is 22

# %%
x , y , z  = 10 , 2 , 2
age= x*y+z #  22

def myage(): 
  global age
  age = 23
  print(f'my age is {age}')

myage()

print("my age is",a)
# Out:
# my age is 23
# my age is 23

# %% [markdown]
# [w3schools](https://www.w3schools.com/)
# Exercise:

# %% [markdown]
# Create a variable called z, assign x + y to it, and display the result.

# %%
x = 5
y = 10
z
z = x + y
print(z)
# Out:
# 15

# %% [markdown]
# Remove the illegal characters in the variable name:
#
# 2my-first_name = "John"

# %%
myfirst_name = "John"

# %% [markdown]
# Insert the correct syntax to assign the same value to all three variables in one code line.
#
# x
#  y
#  z
#  "Orange"

# %%
x=y=z="Orange"

# %% [markdown]
# Insert the correct keyword to make the variable x belong to the global scope.
#
#
#
# ```
# def myfunc():
#
#   ------   x
#   x = "fantastic"
# ```

# %%
def myfunc():
  global   x
  x = "fantastic"
